# %% [markdown]
# # trading_enhancer — exploratory analysis
#
# Sandbox for prototyping features, inspecting model outputs, and
# visualising backtest artifacts. Nothing here is imported by the
# production pipeline.

# %%
import sys, pathlib
ROOT = pathlib.Path.cwd().parent
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load data via the project's data_loader (requires API keys in env).
from src.data_loader import load_data
# bundle = load_data('SPY', lookback_days=120)
# bundle['prices'].tail()

# %%
# Inspect a backtest result if one exists.
out = ROOT / 'data' / 'backtest_out'
if (out / 'equity_curve.csv').exists():
    eq = pd.read_csv(out / 'equity_curve.csv', index_col=0, parse_dates=True)
    eq.plot(title='Equity curve')
    plt.show()
